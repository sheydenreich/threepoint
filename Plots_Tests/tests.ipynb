# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dir_slics="/home/laila/OneDrive/1_Work/5_Projects/02_3ptStatistics/Map3_Covariances/SLICS_theta_4_to_16/"


cov_T1inf_slics=np.loadtxt(dir_slics+"cov_infinite_term1Numerical_sigma_0.37_n_107987.71_thetaMax_7.87_gpu.dat")
cov_T2_slics=np.loadtxt(dir_slics+"cov_square_term2Numerical_sigma_0.37_n_107987.71_thetaMax_7.87_gpu.dat")

cov_T4_slics=np.loadtxt(dir_slics+"cov_infinite_term4Numerical_sigma_0.37_n_107987.71_thetaMax_7.87_gpu.dat")
  

cov_T5_slics=np.loadtxt(dir_slics+"cov_infinite_term5Numerical_sigma_0.37_n_107987.71_thetaMax_7.87_gpu.dat")


cov_T6_slics=np.loadtxt(dir_slics+"cov_square_term6Numerical_sigma_0.37_n_107987.71_thetaMax_7.87_gpu.dat")


cov_T7_slics=np.loadtxt(dir_slics+"cov_infinite_term7Numerical_sigma_0.37_n_107987.71_thetaMax_7.87_gpu.dat")

area_slics=61.9369

# %%
dir_takahashi="/home/laila/OneDrive/1_Work/5_Projects/02_3ptStatistics/Map3_Covariances/Takahashi/"
dir_takahashi2="/home/laila/OneDrive/1_Work/5_Projects/02_3ptStatistics/Map3_Covariances/Takahashi_euclidNz/"
dir_takahashi3="/home/laila/OneDrive/1_Work/5_Projects/02_3ptStatistics/Map3_Covariances/Takahashi_SLICS_Cosmo/"



cov_T1inf_takahashi=np.loadtxt(dir_takahashi+"cov_infinite_term1Numerical_sigma_0.37_n_22209.47_thetaMax_29.32_gpu.dat")
cov_T1inf_takahashi2=np.loadtxt(dir_takahashi2+"cov_infinite_term1Numerical_sigma_0.37_n_22209.47_thetaMax_29.32_gpu.dat")
cov_T1inf_takahashi3=np.loadtxt(dir_takahashi3+"cov_infinite_term1Numerical_sigma_0.37_n_22209.47_thetaMax_29.32_gpu.dat")


cov_T2_takahashi=np.loadtxt(dir_takahashi+"cov_square_term2Numerical_sigma_0.37_n_22209.47_thetaMax_29.32_gpu.dat")
cov_T4_takahashi=np.loadtxt(dir_takahashi+"cov_infinite_term4Numerical_sigma_0.37_n_22209.47_thetaMax_29.32_gpu.dat")
cov_T5_takahashi=np.loadtxt(dir_takahashi+"cov_infinite_term5Numerical_sigma_0.37_n_22209.47_thetaMax_29.32_gpu.dat")
cov_T6_takahashi=np.loadtxt(dir_takahashi+"cov_square_term6Numerical_sigma_0.37_n_22209.47_thetaMax_29.32_gpu.dat")
cov_T7_takahashi=np.loadtxt(dir_takahashi+"cov_infinite_term7Numerical_sigma_0.37_n_22209.47_thetaMax_29.32_gpu.dat")

area_takahashi=859.436692686

# %%
plt.yscale('log')
plt.plot(np.diag(cov_T1inf_slics), label='SLICS, resc')

plt.plot(np.diag(cov_T1inf_takahashi), label='T17')
plt.plot(np.diag(cov_T1inf_takahashi2), label='T17')
plt.plot(np.diag(cov_T1inf_takahashi3), label='T17')


plt.legend()

# %%
plt.yscale('log')
plt.plot(np.diag(cov_T7_slics)*area_slics/area_takahashi, label='SLICS, resc')
plt.plot(np.diag(cov_T7_takahashi), label='T17')
plt.legend()
